# %%
import pandas as pd
import numpy as np
import pokebase as pb

# %%
# Sample to extract a pokemon and access attributes
charizard = pb.pokemon('charizard')
for types in charizard.types:
    if types.slot == 1:
        print('Primary: {}'.format(types.type.name.title()))
    if types.slot == 2:
        print('Secondary: {}'.format(types.type.name.title()))
# Out:
# Primary: Fire
# Secondary: Flying

# %%
# See what data is available based on a pokemon call
charizard = pb.pokemon('charizard')
dir(charizard)
# Out:
# ['_APIResource__force_lookup',
#  '_APIResource__loaded',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_custom',
#  '_load',
#  'abilities',
#  'base_experience',
#  'cries',
#  'endpoint',
#  'forms',
#  'game_indices',
#  'height',
#  'held_items',
#  'id',
#  'id_',
#  'is_default',
#  'location_area_encounters',
#  'moves',
#  'name',
#  'order',
#  'past_abilities',
#  'past_stats',
#  'past_types',
#  'species',
#  'sprites',
#  'stats',
#  'types',
#  'url',
#  'weight']

# %%
# Sample to take a pokemon and create df based on attributes
pkmn = pb.pokemon(1)
pkmn = {
    'id ': pkmn.id,
    'name': pkmn.name.capitalize(),
    'primary_type': pkmn.types[0].type.name.capitalize(),
    'secondary_type': pkmn.types[1].type.name.capitalize() if len(pkmn.types) > 1 else np.nan,
    'hp': pkmn.stats[0].base_stat,
    'attack': pkmn.stats[1].base_stat,
    'defense': pkmn.stats[2].base_stat,
    'special_attack': pkmn.stats[3].base_stat,
    'special_defense': pkmn.stats[4].base_stat,
    'speed': pkmn.stats[5].base_stat
}
pkmn_df = pd.DataFrame([pkmn])
pkmn_df.head()
# Out:
#    id        name primary_type secondary_type  hp  attack  defense  \
# 0    1  Bulbasaur        Grass         Poison  45      49       49
#
#    special_attack  special_defense  speed
# 0              65               65     45
